# %% [markdown]
# ### Get access to Twitter API

# %%
import requests

def get_tweets(username):
    url = f"https://api.twitter.com/2/tweets/search/recent?query=from: {username}"
    payload={}
    headers = {
        'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAD%2ByKQEAAAAA4PVzhiUoV7RuAnqjSXgjjavHu4w%3DUNahJIQhUvvXsjxbF24KB5PvPQ7MG9rHhT12kZxHgryNM2xcez',
        'Cookie': 'personalization_id="v1_w6JBqCOPngR2ZUroGe6tHA=="; guest_id=v1%3A160732850211648950'}
    response = requests.get(url, headers=headers, data=payload)
    if response.status_code != 200:
        return ''
    data = response.json()
    return data

# %% [markdown]
# ### 30 users(samples) with recent 10(or less) tweets

# %%
usernames = ["BarackObama", "justinbieber", "katyperry", "rihanna", "HillaryClinton", "realDonaldTrump", "taylorswift13", "ladygaga", "TheEllenShow", "ArianaGrande", "KimKardashian", "jtimberlake", "selenagomez", "BillGates", "Mike_Pence", "neymarjr", "KingJames", "elonmusk", "chrisbrown", "KevinHart4real", "KylieJenner", "RealDoctorMike", "LoganPaul", "jimmyfallon", "jimmykimmel", "Trevornoah", "DaviBeckham24x7", "jk_rowling", "BorisJohnson", "JeffreeStar"]

# %%
personalities = ["ENTP", "ESFP", "ESFP", "ISFP", "ESTJ", "ESTP", "ESTP", "ISFP", "ENFP", "ESFJ", "ISFJ", "ISFP", "ESFJ", "ENTJ", "ISFJ", "INFJ", "ESFJ", "INTJ", "ESFP", "ESFP", "ISFP", "ENFJ", "ESFP", "ESFJ", "ESFP", "ENFP", "ISFP", "INFP", "ENTP", "ENTJ"]

# %%
get_tweets("KingJames")['data']
# Out:
# [{'id': '1336171178738663426',
#   'text': '@youngchase907 Lil bro you’re a SAVAGE!! 😤😤😤 That’s all I wanted. Lol'},
#  {'id': '1336169281969475584',
#   'text': '🤣🤣🤣🤣🤣🤣🤣!!!! Facts #Browns  🐶🐶🐶 https://t.co/c7XLY0nckN'},
#  {'id': '1336053997724024832',
#   'text': 'RT @morethanavote: GEORGIA: 🚨 TODAY 🚨 is the deadline to register to vote in the runoff‼️\n\n🗳 Served a sentence? You can vote.\n🗳 Turn 18 by…'},
#  {'id': '1336005854114418690', 'text': '@AstronautKI 🙏🏾💨💨💨👑'},
#  {'id': '1335820790919393281',
#   'text': '@tkelce You already know! Love to see and WITNESS 😉 it! 🙏🏾👑🤟🏾'},
#  {'id': '1335820202714402816',
#   'text': 'Throw the powder 💨 up!! Keep going my #IrishBrother🍀 #JustAkidfromAKRON https://t.co/BHACDVLMcM'},
#  {'id': '1335816564264714240',
#   'text': 'BEAST!!! Salute to my G @tkelce 👏🏾👏🏾🙌🏾🙏🏾💪🏾👑 https://t.co/DgFpivHl6V'},
#  {'id': '1335816147661254656', 'text': '@tkelce @SarahSpain 🤣🤣🤣🤣🤣🤣'},
#  {'id': '1335767976499245056',
# ...

# %%
import pandas as pd

df_all = pd.DataFrame()
for username in usernames:
    df = pd.DataFrame(get_tweets(username)['data']).drop("id",axis=1).rename(columns={'text': username}).T
#     df['user'] = username
#     display(df)
    df_all = pd.concat([df_all,df],axis=0)

# %%
df_celebrity = df_all.copy()

# %%
df_celebrity['MBTI'] = personalities

# %%
df_celebrity
# Out:
#                                                                  0  \
# BarackObama      To all of you in Georgia, today is the last da...
# justinbieber     Doing a little something with @tmobile on 12.3...
# katyperry        I love this kind of corporate leadership and v...
# rihanna          woke up feeling like a Sunday in Barbados! If ...
# HillaryClinton   Who do you know in Georgia?\n\nTake a moment n...
# realDonaldTrump  I hope House Republicans will vote against the...
# taylorswift13    @_DionneWarwick I just saw that you tweeted me...
# ladygaga         Thank you for all of the amazing #Chromatica a...
# TheEllenShow     Same weekend. Different month. https://t.co/7s...
# ArianaGrande     🧊☁️ r.e.m. @ultabeauty @bootsuk https://t.co/Q...
# KimKardashian    RT @PhotosOfKanye: @KimKardashian Psalm is Bab...
# jtimberlake      BETTER DAYS \n@fairfightaction @AntClemons \n—...
# selenagomez      RT @TeenVogue: "It's important for me to be au...
# ...

# %%
df_celebrity.shape
# Out:
# (30, 11)

# %% [markdown]
# ### Get more information inside the tweets of that celebrity

# %%
from tqdm import notebook
notebook.tqdm().pandas()

# %%
df_all_id = pd.DataFrame()
for username in usernames:
    df_id = pd.DataFrame(get_tweets(username)['data']).drop("text",axis=1).rename(columns={'id': username}).T
#     display(df_id)
    df_all_id = pd.concat([df_all_id,df_id],axis=0)

# %%
df_all_id.head()
# Out:
#                                   0                    1                    2  \
# BarackObama     1335954913344565258  1334935534809083904  1334928550227550209
# justinbieber    1335992544707145735  1334904494371516419  1334246535480172546
# katyperry       1336214932518391808  1335791131733286916  1335790594279403520
# rihanna         1333825765553491995                  NaN                  NaN
# HillaryClinton  1335980334094159874  1335980134365589505  1335968737204301824
#
#                                   3                    4                    5  \
# BarackObama     1334614947335180289  1334614943379968003  1333833279775141888
# justinbieber                    NaN                  NaN                  NaN
# katyperry       1335714515338584065  1335121172091068416  1334591473610682368
# rihanna                         NaN                  NaN                  NaN
# HillaryClinton  1334929357471617027  1334913385826316288  1334895970069450753
#
# ...

# %%
def get_status(id_num):
    url_id = "https://api.twitter.com/1.1/statuses/lookup.json?id={}".format(id_num)
    payload={}
    headers = {
        'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAD%2ByKQEAAAAA4PVzhiUoV7RuAnqjSXgjjavHu4w%3DUNahJIQhUvvXsjxbF24KB5PvPQ7MG9rHhT12kZxHgryNM2xcez',
        'Cookie': 'personalization_id="v1_w6JBqCOPngR2ZUroGe6tHA=="; guest_id=v1%3A160732850211648950'}
    response = requests.get(url_id, headers=headers, data=payload)
    if response.status_code != 200:
        return ''
    data = response.json()
    return data

# %%
get_status(1335954913344565258) # have a look on 1st id
# Out:
# [{'created_at': 'Mon Dec 07 14:30:46 +0000 2020',
#   'id': 1335954913344565258,
#   'id_str': '1335954913344565258',
#   'text': 'To all of you in Georgia, today is the last day to register to vote in the upcoming runoff election. Take a few min… https://t.co/Jif3Gd7NpQ',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Jif3Gd7NpQ',
#      'expanded_url': 'https://twitter.com/i/web/status/1335954913344565258',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 813286,
#    'id_str': '813286',
#    'name': 'Barack Obama',
#    'screen_name': 'BarackObama',
# ...

# %%
df_status = pd.DataFrame(get_status(1335954913344565258)).select_dtypes(include='number').drop('id',axis=1)

# %%
df_status
# Out:
#    favorite_count  retweet_count
# 0           29189           8164

# %%
df_status.T.to_dict()[0]
# Out:
# {'favorite_count': 29189, 'retweet_count': 8164}
